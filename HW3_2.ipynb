# %% [markdown]
# <a href="https://colab.research.google.com/github/EbrahimNouri/AI_HW/blob/main/HW3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PART 1

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive') # Mount to a path without spaces

# Replace 'your_file.csv' with the actual name of your CSV file
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')

# Display the first few rows of the DataFrame
print(len(df))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 768

# %%
# Fill null values with the mean of each column
df_filled = df.fillna(df.mean()).round(0)

# Display the DataFrame with filled null values
display(df_filled)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    156.0  34.0
# 1              1     85.0           66.0           29.0    156.0  27.0
# 2              8    183.0           64.0           29.0    156.0  23.0
# 3              1     89.0           66.0           23.0     94.0  28.0
# 4              0    137.0           40.0           35.0    168.0  43.0
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  33.0
# 764            2    122.0           70.0           27.0    156.0  37.0
# 765            5    121.0           72.0           23.0    112.0  26.0
# 766            1    126.0           60.0           29.0    156.0  30.0
# 767            1     93.0           70.0           31.0    156.0  30.0
#
#      DiabetesPedigree  Age  Outcome
# 0                 1.0   50        1
# 1                 0.0   31        0
# ...

# %%
df_filled.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    156.0  34.0
# 1            1     85.0           66.0           29.0    156.0  27.0
# 2            8    183.0           64.0           29.0    156.0  23.0
# 3            1     89.0           66.0           23.0     94.0  28.0
# 4            0    137.0           40.0           35.0    168.0  43.0
#
#    DiabetesPedigree  Age  Outcome
# 0               1.0   50        1
# 1               0.0   31        0
# 2               1.0   32        1
# 3               0.0   21        0
# 4               2.0   33        1

# %% [markdown]
# # PART 2

# %%
# Create a new DataFrame with the specified columns
new_df = df_filled[['Glucose', 'BloodPressure', 'BMI', 'Age', 'Insulin', 'Outcome']]

# Display the new DataFrame
display(new_df)
# Out:
#      Glucose  BloodPressure   BMI  Age  Insulin  Outcome
# 0      148.0           72.0  34.0   50    156.0        1
# 1       85.0           66.0  27.0   31    156.0        0
# 2      183.0           64.0  23.0   32    156.0        1
# 3       89.0           66.0  28.0   21     94.0        0
# 4      137.0           40.0  43.0   33    168.0        1
# ..       ...            ...   ...  ...      ...      ...
# 763    101.0           76.0  33.0   63    180.0        0
# 764    122.0           70.0  37.0   27    156.0        0
# 765    121.0           72.0  26.0   30    112.0        0
# 766    126.0           60.0  30.0   47    156.0        1
# 767     93.0           70.0  30.0   23    156.0        0
#
# [768 rows x 6 columns]

# %%
# Calculate the correlation matrix
correlation_matrix = new_df.corr()

# Display the correlation matrix
display(correlation_matrix)
# Out:
#                 Glucose  BloodPressure       BMI       Age   Insulin   Outcome
# Glucose        1.000000       0.218530  0.230835  0.266507  0.420052  0.492935
# BloodPressure  0.218530       1.000000  0.279443  0.324915  0.072906  0.165723
# BMI            0.230835       0.279443  1.000000  0.027734  0.166109  0.310830
# Age            0.266507       0.324915  0.027734  1.000000  0.137296  0.238356
# Insulin        0.420052       0.072906  0.166109  0.137296  1.000000  0.214519
# Outcome        0.492935       0.165723  0.310830  0.238356  0.214519  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()
