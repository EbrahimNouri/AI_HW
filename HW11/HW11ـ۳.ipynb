# %%
import kagglehub
import pandas as pd

# %%
path = kagglehub.dataset_download("uciml/pima-indians-diabetes-database")

# print("Path to dataset files:", path)
X = pd.read_csv(path + "/diabetes.csv")
X.head()
print(20 * '#', "\t\tShape:\t\t", 20 * "#", "\n", X.shape)
print(20 * '#', "\t\tData Types:\t\t", 20 * "#", "\n", X.dtypes)
print(20 * '#', "\t\tDescribe:\t\t", 20 * "#", "\n", X.describe())
# Out:
# #################### 		Shape:		 ####################
#  (768, 9)
# #################### 		Data Types:		 ####################
#  Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object
# #################### 		Describe:		 ####################
#         Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# ...

# %%
columns_to_fix = ["BMI", "Glucose", "BloodPressure", "SkinThickness", "Insulin"]

for column in columns_to_fix:
    zero_count = (X[column] == 0).sum()
    zero_percent = (X[column] == 0).sum() / len(X) * 100
    print("for column: ", column, " zero_count: " + str(zero_count), "zero_percent: " + str(zero_percent))
# Out:
# for column:  BMI  zero_count: 11 zero_percent: 1.4322916666666665
# for column:  Glucose  zero_count: 5 zero_percent: 0.6510416666666667
# for column:  BloodPressure  zero_count: 35 zero_percent: 4.557291666666666
# for column:  SkinThickness  zero_count: 227 zero_percent: 29.557291666666668
# for column:  Insulin  zero_count: 374 zero_percent: 48.69791666666667

# %%
X[columns_to_fix] = X[columns_to_fix].replace(0, None)
print(X.isnull().sum())
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
X_fill_mean = X[columns_to_fix].fillna(X[columns_to_fix].mean(), inplace=False)
X_fill_mean.isnull().sum()
# Out:
# /var/folders/d2/06nz1xzj2wggjy6p6ghmjdrc0000gn/T/ipykernel_2407/567957745.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X_fill_mean = X[columns_to_fix].fillna(X[columns_to_fix].mean(), inplace=False)
# BMI              0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# dtype: int64
