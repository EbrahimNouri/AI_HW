# %% [markdown]
# <a href="https://colab.research.google.com/github/EbrahimNouri/AI_HW/blob/main/HW3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PART 1

# %%
import numpy as np

# Define the number of cities and days
num_cities = 6
num_days = 30

# Create column names for days (e.g., Day_1, Day_2, ...)
day_columns = [f'Day_{i+1}' for i in range(num_days)]

# Create row names for cities (e.g., City_1, City_2, ...)
# city_rows = [f'City_{i+1}' for i in range(num_cities)]
city_rows = ['Tehran', 'Mashhad', 'Isfahan', 'Tabriz', 'Shiraz', 'Ahvaz']

# Generate random temperatures for 6 cities over 30 days (15 to 40 degrees Celsius)
city_temperatures = np.random.randint(15, 41, size=(num_cities, num_days))

# Generate random humidity for 6 cities over 30 days (20% to 80%)
city_humidity = np.random.randint(20, 81, size=(num_cities, num_days))

# Generate random rainfall for 6 cities over 30 days (0mm to 50mm)
city_rainfall = np.random.randint(0, 51, size=(num_cities, num_days))

print("NumPy arrays for temperatures, humidity, and rainfall have been generated.")
# Out:
# NumPy arrays for temperatures, humidity, and rainfall have been generated.

# %% [markdown]
# # PART 2

# %%
import pandas as pd

# Convert the numpy arrays to pandas DataFrames
df_city_temperatures = pd.DataFrame(
    city_temperatures,
    index=city_rows,
    columns=day_columns
)

df_city_humidity = pd.DataFrame(
    city_humidity,
    index=city_rows,
    columns=day_columns
)

df_city_rainfall = pd.DataFrame(
    city_rainfall,
    index=city_rows,
    columns=day_columns
)

print("DataFrame for Temperatures:")
display(df_city_temperatures)

print("\nDataFrame for Humidity:")
display(df_city_humidity)

print("\nDataFrame for Rainfall:")
display(df_city_rainfall)
# Out:
# DataFrame for Temperatures:
#          Day_1  Day_2  Day_3  Day_4  Day_5  Day_6  Day_7  Day_8  Day_9  \
# Tehran      19     38     31     22     36     19     37     19     16
# Mashhad     16     36     16     19     25     21     28     32     17
# Isfahan     38     37     40     31     30     40     33     27     17
# Tabriz      33     31     17     30     37     21     38     25     26
# Shiraz      38     25     40     29     36     28     16     27     33
# Ahvaz       21     25     33     37     19     21     28     31     39
#
#          Day_10  ...  Day_21  Day_22  Day_23  Day_24  Day_25  Day_26  Day_27  \
# Tehran       23  ...      22      30      33      15      25      26      39
# Mashhad      17  ...      39      17      36      33      25      18      36
# Isfahan      33  ...      24      17      27      29      38      35      33
# Tabriz       21  ...      34      29      16      17      26      21      40
# Shiraz       39  ...      32      21      22      38      23      31      23
# Ahvaz        27  ...      27      21      16      28      23      36      37
#
#          Day_28  Day_29  Day_30
# Tehran       40      26      27
# Mashhad      30      35      21
# Isfahan      19      31      30
# Tabriz       17      39      15
# Shiraz       29      18      36
# Ahvaz        35      31      15
#
# [6 rows x 30 columns]
# DataFrame for Humidity:
#          Day_1  Day_2  Day_3  Day_4  Day_5  Day_6  Day_7  Day_8  Day_9  \
# Tehran      41     53     36     63     37     20     22     69     71
# Mashhad     57     63     32     52     38     68     75     75     52
# Isfahan     57     30     23     50     58     36     55     47     41
# Tabriz      37     70     22     61     78     55     76     80     29
# Shiraz      43     67     71     32     46     38     65     24     58
# Ahvaz       37     70     76     80     61     47     37     69     56
#
#          Day_10  ...  Day_21  Day_22  Day_23  Day_24  Day_25  Day_26  Day_27  \
# Tehran       27  ...      37      51      23      61      54      77      38
# Mashhad      44  ...      44      37      72      69      27      77      46
# Isfahan      35  ...      43      55      74      38      71      73      57
# Tabriz       78  ...      77      67      29      27      32      43      46
# Shiraz       36  ...      76      26      29      80      47      36      61
# Ahvaz        20  ...      61      46      33      60      53      61      73
#
#          Day_28  Day_29  Day_30
# Tehran       31      33      22
# Mashhad      41      50      51
# Isfahan      78      76      49
# Tabriz       52      28      47
# Shiraz       62      69      70
# Ahvaz        70      32      46
#
# [6 rows x 30 columns]
# DataFrame for Rainfall:
#          Day_1  Day_2  Day_3  Day_4  Day_5  Day_6  Day_7  Day_8  Day_9  \
# Tehran      13     34     10     22     13     49     47     27     13
# Mashhad     31      0     40     27     37      5     43     15     11
# Isfahan     21      0     33     37     17     38     40     25     17
# Tabriz      39     14     39     37      9     16     17     37     47
# Shiraz       6     13     31     10     19     16     29     29     40
# Ahvaz       42      6     43      5     27     23      4      4     11
#
#          Day_10  ...  Day_21  Day_22  Day_23  Day_24  Day_25  Day_26  Day_27  \
# Tehran       46  ...       6      45       5      30      29      43      22
# Mashhad      26  ...      12      49      20      30       5      28       9
# Isfahan      50  ...      11       0      35       2      29      39      37
# Tabriz        6  ...      42      16       4      12      47      42      14
# Shiraz       27  ...      35      49      10      20      22      48      46
# Ahvaz        29  ...      49      44       4      25       0       5      12
#
#          Day_28  Day_29  Day_30
# Tehran       49       8       2
# Mashhad      31      31      23
# Isfahan       6       2      42
# Tabriz       45      16      39
# Shiraz       29      37       6
# Ahvaz        40      10      25
#
# [6 rows x 30 columns]

# %%
import pandas as pd

# Ensure city_rows, day_columns, df_city_temperatures, df_city_humidity, df_city_rainfall are available from previous steps

# Melt the temperature DataFrame
df_temp_melted = df_city_temperatures.reset_index().melt(
    id_vars='index',
    var_name='Day',
    value_name='Temperature'
)
df_temp_melted = df_temp_melted.rename(columns={'index': 'City'})

# Melt the humidity DataFrame
df_humidity_melted = df_city_humidity.reset_index().melt(
    id_vars='index',
    var_name='Day',
    value_name='Humidity'
)
df_humidity_melted = df_humidity_melted.rename(columns={'index': 'City'})

# Melt the rainfall DataFrame
df_rainfall_melted = df_city_rainfall.reset_index().melt(
    id_vars='index',
    var_name='Day',
    value_name='Rainfall'
)
df_rainfall_melted = df_rainfall_melted.rename(columns={'index': 'City'})

# Merge the melted DataFrames
weather_df = pd.merge(df_temp_melted, df_humidity_melted, on=['City', 'Day'])
weather_df = pd.merge(weather_df, df_rainfall_melted, on=['City', 'Day'])

# Convert 'Day' column from 'Day_X' string to integer X
weather_df['Day'] = weather_df['Day'].str.replace('Day_', '').astype(int)

# Display the first few rows of the combined DataFrame
print("Combined Weather DataFrame:")
display(weather_df)

# Optionally, display information about the DataFrame to check data types and non-null counts
print("\nDataFrame Info:")
weather_df.info()
# Out:
# Combined Weather DataFrame:
#         City  Day  Temperature  Humidity  Rainfall
# 0     Tehran    1           19        41        13
# 1    Mashhad    1           16        57        31
# 2    Isfahan    1           38        57        21
# 3     Tabriz    1           33        37        39
# 4     Shiraz    1           38        43         6
# ..       ...  ...          ...       ...       ...
# 175  Mashhad   30           21        51        23
# 176  Isfahan   30           30        49        42
# 177   Tabriz   30           15        47        39
# 178   Shiraz   30           36        70         6
# 179    Ahvaz   30           15        46        25
#
# [180 rows x 5 columns]
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         180 non-null    object
#  1   Day          180 non-null    int64
#  2   Temperature  180 non-null    int64
#  3   Humidity     180 non-null    int64
#  4   Rainfall     180 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # PART 3 - 1

# %%
average_weather_per_city = weather_df.groupby('City').agg({
    'Temperature': 'mean',
    'Humidity': 'mean',
    'Rainfall': 'mean'
})

print("میانگین دما، رطوبت و بارندگی برای هر شهر:")
display(average_weather_per_city)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3720200263.py in <cell line: 0>()
# ----> 1 average_weather_per_city = weather_df.groupby('City').agg({
#       2     'Temperature': 'mean',
#       3     'Humidity': 'mean',
#       4     'Rainfall': 'mean'
#       5 })
#
# NameError: name 'weather_df' is not defined

# %% [markdown]
# # PART 3 - 2

# %%
warmest_city = average_weather_per_city['Temperature'].idxmax()
warmest_temp = average_weather_per_city['Temperature'].max()

coldest_city = average_weather_per_city['Temperature'].idxmin()
coldest_temp = average_weather_per_city['Temperature'].min()

print(f"Warmest City: {warmest_city} (Average Temperature: {warmest_temp:.2f}°C)")
print(f"Coldest City: {coldest_city} (Average Temperature: {coldest_temp:.2f}°C)")
# Out:
# Warmest City: Shiraz (Average Temperature: 30.70°C)
# Coldest City: Ahvaz (Average Temperature: 25.77°C)

# %% [markdown]
# #PART 3 - 3

# %%
rainy_days_per_city = weather_df[weather_df['Rainfall'] > 10].groupby('City').size()

print("تعداد روزهای بارانی برای هر شهر (بارندگی بیش از 10 میلی‌متر):")
display(rainy_days_per_city)
# Out:
# تعداد روزهای بارانی برای هر شهر (بارندگی بیش از 10 میلی‌متر):
# City
# Ahvaz      19
# Isfahan    24
# Mashhad    24
# Shiraz     23
# Tabriz     25
# Tehran     23
# dtype: int64

# %% [markdown]
# #PART 4

# %%
import matplotlib.pyplot as plt

# Filter data for Isfahan
isfahan_data = weather_df[weather_df['City'] == 'Isfahan']

# Extract temperature and humidity for Isfahan
isfahan_temperature = isfahan_data['Temperature']
isfahan_humidity = isfahan_data['Humidity']

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(isfahan_temperature, isfahan_humidity, color='blue', alpha=0.7)

# Set title and labels
plt.title('Temperature - Humidity - Isfahan 30 days')
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity (%)')

# Add grid for better readability
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # PART 6
